# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score

df = pd.read_csv('data.csv')
X=df[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
y=df["Species"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)
model=DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
accuracy= accuracy_score(y_test,y_pred)
recall= recall_score(y_test,y_pred, average='macro')
precision= precision_score(y_test,y_pred, average='macro')

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')
X=df[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
y=df["Species"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)
model=DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot=True,fmt='d')
plt.ylabel("True")
plt.xlabel("Predicted")

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')
X=df[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
y=df["Species"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)
model=DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
plot_tree(model,filled=True)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, recall_score

df = pd.read_csv('data.csv')
X=df[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
y=df["Species"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)
model=DecisionTreeClassifier(max_depth=3)
model.fit(X_train, y_train)
y_pred_test=model.predict(X_test)
y_pred_train=model.predict(X_train)

accuracy_train= accuracy_score(y_train,y_pred_train)
recall_train= recall_score(y_train,y_pred_train, average='macro')
accuracy_test= accuracy_score(y_test,y_pred_test)
recall_test= recall_score(y_test,y_pred_test, average='macro')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import recall_score

# Load the dataset
df = pd.read_csv('data.csv')
X=df[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
y=df["Species"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)
max_depth =[1,2,3]
min_sample_leaf = [2,3,5]
model = DecisionTreeClassifier()
param_grid = {
    'max_depth': max_depth,
    'min_samples_leaf': min_sample_leaf
}   
grid_search = GridSearchCV(model, param_grid, scoring='recall_macro', cv=5)
grid_search.fit(X_train, y_train)   
best_params = grid_search.best_params_
best_recall = grid_search.best_score_
best_model = grid_search.best_estimator_
y_pred_test=best_model.predict(X_test)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
df = pd.read_csv('data.csv')
X=df[["mpg","cylinders","displacement","horsepower","weight","acceleration","model year","origin"]]
y= X["origin"]
X.drop(columns=["origin"], axis=1, inplace=True)
X_dummies = pd.get_dummies(X,columns=['model year'], dtype=float)
X_train, X_test, y_train, y_test = train_test_split(
    X_dummies, y, test_size=0.20
)
dtree = DecisionTreeClassifier(random_state=1)
dtree.fit(X_train, y_train)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score
df = pd.read_csv('data.csv')
X=df[["mpg","cylinders","displacement","horsepower","weight","acceleration","model year","origin"]]
y= X["origin"]
X.drop(columns=["origin"], axis=1, inplace=True)
X_dummies = pd.get_dummies(X,columns=['model year'], dtype=float)
X_train, X_test, y_train, y_test = train_test_split(
    X_dummies, y, test_size=0.30
)
dtree = DecisionTreeClassifier(random_state=1)
dtree.fit(X_train, y_train)
y_pred_train=dtree.predict(X_train)
train_acc= accuracy_score(y_train,y_pred_train)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score
df = pd.read_csv('data.csv')
X=df[["mpg","cylinders","displacement","horsepower","weight","acceleration","model year","origin"]]
y= X["origin"]
X.drop(columns=["origin"], axis=1, inplace=True)
X_dummies = pd.get_dummies(X,columns=['model year'], dtype=float)
X_train, X_test, y_train, y_test = train_test_split(
    X_dummies, y, test_size=0.30, random_state=1
)
dtree = DecisionTreeClassifier(max_depth=9, random_state=1)
dtree.fit(X_train, y_train)
y_pred_train=dtree.predict(X_train)
train_acc= accuracy_score(y_train,y_pred_train)
y_pred_test=dtree.predict(X_test)
test_acc= accuracy_score(y_test,y_pred_test)
overfitting = 1 if test_acc > train_acc + 0.1 else 0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score, recall_score, precision_score
from matplotlib import pyplot as plt


df = pd.read_csv('data.csv')
X=df[["mpg","cylinders","displacement","horsepower","weight","acceleration","model year","origin"]]
y= X["origin"]
X.drop(columns=["origin"], axis=1, inplace=True)
X_dummies = pd.get_dummies(X,columns=['model year'], dtype=float)
X_train, X_test, y_train, y_test = train_test_split(
    X_dummies, y, test_size=0.30, random_state=1
)
dtree = DecisionTreeClassifier(max_depth=3, random_state=1)
dtree.fit(X_train, y_train)
y_pred_train=dtree.predict(X_train)
train_acc= accuracy_score(y_train,y_pred_train)
y_pred_test=dtree.predict(X_test)
test_acc= accuracy_score(y_test,y_pred_test)
tree_plot = plot_tree(dtree, filled=True)
root_node_name = 'displacement'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from matplotlib import pyplot as plt


df = pd.read_csv('data.csv')
X=df[["mpg","cylinders","displacement","horsepower","weight","acceleration","model year","origin"]]
y= X["origin"]
X.drop(columns=["origin"], axis=1, inplace=True)
X_dummies = pd.get_dummies(X,columns=['model year'], dtype=float)
X_train, X_test, y_train, y_test = train_test_split(
    X_dummies, y, test_size=0.30, random_state=1
)
dtree = DecisionTreeClassifier(max_depth=3, random_state=1)
dtree.fit(X_train, y_train)
y_pred_train=dtree.predict(X_train)
train_acc= accuracy_score(y_train,y_pred_train)
y_pred_test=dtree.predict(X_test)
test_acc= accuracy_score(y_test,y_pred_test)
tree_plot = plot_tree(dtree, filled=True)
root_node_name = 'displacement'
