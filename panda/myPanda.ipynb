# %% [markdown]
# Learn Panda

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import requests

# url= 'https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv'
# response = requests.get(url)
# with open('olympics.csv', 'wb') as f:
#     f.write(response.content)   


#oo = pd.read_csv('olympics.csv', skiprows=5, header=6 )    
oo = pd.read_csv('olympics.csv', skiprows=5)    

#oo.sample(15)
#oo.shape
#oo.columns
#oo.head(10)
#oo.sample(10)
#oo.describe()
#oo.groupby(['Sport', 'Medal']).size().unstack().plot(kind='bar', stacked=True, figsize=(10,5))
#oo.Sport.unique().__contains__('Tennis')
#oo.groupby(['Sport', 'Medal']).size().unstack().plot(kind='bar', stacked=True, figsize=(10,5))
#oo.Year.unique()
#oo.Medal.count()
#oo.Medal.value_counts()
oo.groupby(['Medal','Event Gender']).size().unstack().plot(kind='bar', stacked=False, figsize=(10,5))
# Out:
# <Axes: xlabel='Medal'>
