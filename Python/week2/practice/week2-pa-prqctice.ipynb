# %%
# import pandas as pd
# import numpy as np  

# a = pd.read_csv('books.csv')
# #a.shape
# #a.describe()
# #a.info()
# # count = (a['average_rating'] > 4).sum()
# # print (count) 
# # a.loc[(a['average_rating'] > 4.5) & (a['average_rating'] < 10)]

# #6
# #a[(a['average_rating'] > 4.5) & (a['average_rating'] < 10)]

# #7
# # a.groupby(['language_code'])['average_rating'].mean()
# #a[a['language_code'] == 'eng'].groupby(['language_code'])['average_rating'].mean()

# #8
# #a.iloc[0:5, 0:4]

# #9
# # a.loc[[1,4], ['language_code','num_pages','ratings_count']]

# #10
# # print(a['num_pages'].mean()) # corre cvalue 
# # print(a['num_pages'].median())
# # print(a['num_pages'].max())
# # print(a['num_pages'].mode()) 

# #11
# # a[a['year'] == 2010].groupby(['year'])['year'].count()

# #12
# # a[(a['publisher'] == 'DAW') & (a['average_rating'] > 4) ]

# #13
# #a[(a['num_pages'] > 500) & (a['year'] > 2010)].groupby(['language_code'])['language_code'].count()

# #14
# #a[(a['author'] == 'Agatha Christie')].groupby(['author'])['author'].count()

# #15
# #a[(a['language_code'] == 'spa') & (a['year'] > 2000)].groupby(['language_code'])['language_code'].count()

# #==================================
# Out:
# language_code
# spa    84
# Name: language_code, dtype: int64

# %% [markdown]
# to do Panda
#
# - Filter data and count
# - Check data boolean operation, set true or false
# - Filter data, group, and count items in a group
# - Filter and count rows or items
# - Get column data type
# - Add column with calculated data
# - Add series and DataFrame
# - DataFrame: add, multiply

# %%
import pandas as pd
import numpy as np

#load data
df_original = pd.read_csv('books.csv')
df_original.head()
#df_original.shape

#filter data 
# books pages between 300 and 400 
filter = (df_original['num_pages'] > 300) & (df_original['num_pages'] < 400)
df_filter1 = df_original[filter]
#df_filter1["filter"] = [df_filter1["num_pages"]] * len(df_filter1)
df_filter1.head()
df_filter1.count()
(df_filter1['average_rating']> 4).sum()
df_filter1['author'].notna().sum()
df_filter1.iloc[0:10, 0:4]

# Select specific rows and columns using index and column filtering
# df_filtered = df_filter1.loc[0:10, ['title', 'author', 'num_pages']]
# df_filtered





# books with highest rating
# books with lowest rating
# Out:
#                                                 title               author  \
# 2                                   Breach of Promise     James Scott Bell
# 4   The Killing Dance (Anita Blake  Vampire Hunter...  Laurell K. Hamilton
# 10              The Well At The World's End: Volume I       William Morris
# 11                      Merlin's Tour of the Universe  Neil deGrasse Tyson
# 19       The Beleaguered City: The Vicksburg Campaign         Shelby Foote
# 25                                       Open Secrets          Alice Munro
# 27  Philosophical Papers: Volume 1  Human Agency a...       Charles Taylor
# 29                          Shoofly Pie (Bug Man  #1)            Tim Downs
# 40  The Walking Dead  Book One (The Walking Dead #...       Robert Kirkman
# 44                                Pride and Prejudice          Jane Austen
#
#     average_rating         isbn13
# 2             4.00  9780310243878
# 4             4.13  9780425209066
# 10            3.81  9781587150883
# ...
